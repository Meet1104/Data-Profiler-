# %% [markdown]
# # Part A: Fundamentals

# %% [markdown]
# ## 1. What is Data Analysis?
#
# ### Definition
# Data Analysis is the process of inspecting, cleaning, transforming, and modeling data with the goal of discovering useful information, drawing conclusions, and supporting decision-making. It is a crucial step before building any machine learning or AI system, as it helps us understand the story hidden inside data.
#
# ### Purpose
# The main purpose of data analysis is to:
#
# - Understand the structure and quality of the dataset
# - Identify patterns, trends, and relationships within the data
# - Detect anomalies or outliers that may impact results
# - Support business decisions with data-driven insights
#
# ### Objective
#
# After studying this section, learners should be able to:
#
# - Explain what data analysis is and why it is important
# - Differentiate between descriptive, diagnostic, predictive, and prescriptive analysis
# - Apply basic Python tools (like Pandas, NumPy, Matplotlib) to perform Exploratory Data Analysis (EDA)
# - Make preliminary insights from raw data
#
# ### Syntax / Implementation (Python)
#
# In Python, data analysis usually starts with importing required libraries:
#
# - import pandas as pd
# - import numpy as np
# - import matplotlib.pyplot as plt
# - import seaborn as sns
#
# ### Real-World Example 🌍
#
# Imagine a retail store wants to know which products sell the most during festivals. By analyzing past sales data, they can:
#
# - Identify the top-selling products
# - Plan stock levels to avoid shortages
# - Launch targeted promotions for specific items
#
# ### Technical Example ⚙️
#
# In Machine Learning, before training a model on a dataset, we analyze:
#
# - Distribution of features (e.g., age, income, product price)
# - Missing values and their handling strategy
# - Correlation between independent variables and the target variable

# %% [markdown]
# ## 2. Steps to Plan a Data Science Project.
#
# A typical Data Science project follows these steps:
#
# 1. **Problem Definition**
#    - Clearly define the objective (e.g., predict customer churn)
#
# 2. **Data Collection**
#    - Gather data from sources like databases, APIs, CSV files
#
# 3. **Data Cleaning**
#    - Handle missing values, duplicates, and inconsistencies
#
# 4. **Exploratory Data Analysis (EDA)**
#    - Understand patterns, distributions, and relationships
#
# 5. **Feature Engineering**
#    - Create new features and select important ones
#
# 6. **Model Building**
#    - Choose and train machine learning models
#
# 7. **Model Evaluation**
#    - Evaluate using metrics like accuracy, precision, recall
#
# 8. **Deployment**
#    - Deploy the model in real-world applications
#
# 9. **Monitoring & Maintenance**
#    - Track performance and update when needed

# %% [markdown]
# ## 3. Machine Learning Problem Statement
#
# ### Problem:
# Predict whether a customer will churn based on their purchase behavior.
#
# ### Objective:
# Build a classification model that predicts if a customer will leave (churn) or stay.
#
# ### Input Features:
# - Purchase frequency
# - Total spending
# - Last purchase date
# - Product categories
# - Customer demographics
#
# ### Output:
# - Churn (Yes / No)
#
# ### Type of Problem:
# - Supervised Learning
# - Classification Problem
#
# ### Use Case:
# - Helps businesses retain customers
# - Enables targeted marketing strategies
# - Improves customer satisfaction

# %% [markdown]
# ## 4. Explain: What are Tensors?
#
# ### Definition
# A Tensor is a multi-dimensional array or data structure used to represent data in mathematics, physics, and machine learning. It is a generalization of scalars, vectors, and matrices to higher dimensions.
#
# ### Types of Tensors
#
# - **Scalar (0D Tensor)**
#   A single value
#   Example: 5
#
# - **Vector (1D Tensor)**
#   A list of values
#   Example: [1, 2, 3]
#
# - **Matrix (2D Tensor)**
#   A 2D table of values
#   Example:
#   [[1, 2],
#    [3, 4]]
#
# - **Higher-Dimensional Tensor (3D and above)**
#   Example: Data used in images, videos, etc.
#
# ---
#
# ### Explanation with NumPy Examples
#
# In Python, tensors can be represented using NumPy arrays:
#
# ```python
# import numpy as np
#
# # Scalar (0D Tensor)
# scalar = np.array(10)
# print("Scalar:", scalar)
#
# # Vector (1D Tensor)
# vector = np.array([1, 2, 3])
# print("Vector:", vector)
#
# # Matrix (2D Tensor)
# matrix = np.array([[1, 2], [3, 4]])
# print("Matrix:\n", matrix)
#
# # 3D Tensor
# tensor_3d = np.array([
#     [[1, 2], [3, 4]],
#     [[5, 6], [7, 8]]
# ])
# print("3D Tensor:\n", tensor_3d)

# %% [markdown]
# # Part B : Data Acquisition

# %% [markdown]
# ### 5. Import datasets from different souurce:

# %%
import requests
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv("sample_data.csv")

# %%
df2 = pd.read_json("sample_data.json")

# %%
with open("sample_data.sql",'r') as file :
    sql_script = file.read()

# %%
url = "https://jsonplaceholder.typicode.com/users"

response = requests.get(url)

if response.status_code == 200:
    data = response.json()   
    
    df4 = pd.DataFrame(data)
    
    print("Data fetched successfully!\n")
else:
    print("Failed to fetch data")
# Out:
# Data fetched successfully!

# %% [markdown]
# # Part C : Data Understanding & Cleaning

# %% [markdown]
# ### 6. Perform initial exploration:

# %%
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      10 non-null     int64
#  1   Name            10 non-null     object
#  2   Age             10 non-null     int64
#  3   City            10 non-null     object
#  4   PurchaseAmount  10 non-null     int64
#  5   Churn           10 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 612.0+ bytes
#        CustomerID        Age  PurchaseAmount
# count    10.00000  10.000000       10.000000
# mean      5.50000  27.700000     1480.000000
# std       3.02765   3.772709      522.387681
# min       1.00000  22.000000      800.000000
# 25%       3.25000  25.250000     1125.000000
# 50%       5.50000  27.500000     1450.000000
# 75%       7.75000  29.750000     1750.000000
# max      10.00000  35.000000     2500.000000

# %%
df2.head()
df2.info()
df2.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      10 non-null     int64
#  1   Name            10 non-null     object
#  2   Age             10 non-null     int64
#  3   City            10 non-null     object
#  4   PurchaseAmount  10 non-null     int64
#  5   Churn           10 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 612.0+ bytes
#        CustomerID        Age  PurchaseAmount
# count    10.00000  10.000000       10.000000
# mean      5.50000  27.700000     1480.000000
# std       3.02765   3.772709      522.387681
# min       1.00000  22.000000      800.000000
# 25%       3.25000  25.250000     1125.000000
# 50%       5.50000  27.500000     1450.000000
# 75%       7.75000  29.750000     1750.000000
# max      10.00000  35.000000     2500.000000

# %%
df4.head()
df4.info()
df4.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        10 non-null     int64
#  1   name      10 non-null     object
#  2   username  10 non-null     object
#  3   email     10 non-null     object
#  4   address   10 non-null     object
#  5   phone     10 non-null     object
#  6   website   10 non-null     object
#  7   company   10 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 772.0+ bytes
#              id
# count  10.00000
# mean    5.50000
# std     3.02765
# min     1.00000
# 25%     3.25000
# 50%     5.50000
# 75%     7.75000
# max    10.00000

# %% [markdown]
# ### 7. Apply Data Cleaning

# %%
df.isnull().sum()
# Out:
# CustomerID        0
# Name              0
# Age               0
# City              0
# PurchaseAmount    0
# Churn             0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# CustomerID        0
# Name              0
# Age               0
# City              0
# PurchaseAmount    0
# Churn             0
# dtype: int64

# %%
df4.isnull().sum()
# Out:
# id          0
# name        0
# username    0
# email       0
# address     0
# phone       0
# website     0
# company     0
# dtype: int64

# %% [markdown]
# # Part D: Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 8.Distribution of Age, PurchaseAmount

# %%
# Age distribution
plt.figure()
plt.hist(df["Age"])
plt.title("Age Distribution")
plt.show()

# Purchase Amount distribution
plt.figure()
plt.hist(df["PurchaseAmount"])
plt.title("Purchase Amount Distribution")
plt.show()

# %% [markdown]
# ### 9.(i) Relationship between City & PurchaseAmount

# %%
plt.figure()
sns.boxplot(x="City", y="PurchaseAmount", data=df)
plt.title("City vs Purchase Amount")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### (ii) Relationship between PurchaseAmount & Churn

# %%
plt.figure()
sns.boxplot(x="Churn", y="PurchaseAmount", data=df)
plt.title("Purchase Amount vs Churn")
plt.show()

# %% [markdown]
# ### 10. Multivariate Analysis

# %% [markdown]
# ### (i) Correlation Heatmap

# %%
plt.figure()
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ### (ii) Pair Plot

# %%
sns.pairplot(df)
plt.show()

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# Load dataset
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv")

# Generate report
profile = ProfileReport(df, title="Titanic Dataset Report", explorative=True)

# Save to HTML
profile.to_file("titanic_report.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 249.50it/s]
